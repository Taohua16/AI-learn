# %% [markdown]
# <h1 align="center"> Week 2 - CNN基础与 ResNet </h1>
#
# <p style="text-align:center">汇报人：修改为你自己的姓名</p>
#
# ---

# %% [markdown]
# ###  建议学习资料：
#
# - [李沐动手学深度学习16-29](https://space.bilibili.com/1567748478/lists/358497?type=series)
#
#
# ###  本周任务清单：
#
# 1.  **理论学习**
#    - 了解卷积神经网络（CNN）的基本原理与结构组成
#    - 掌握卷积层、池化层（Max Pooling / Avg Pooling）、批归一化（Batch Normalization）的作用与工作机制
#    - 理解残差网络（ResNet）的设计思想与核心模块（残差连接、Bottleneck）
# 2.  **实践任务**
#    - 根据[源码](https://github.com/CathIAS/TLIO)复现基于Resnet的[TLIO](https://ieeexplore.ieee.org/document/9134860)模型，完成imu数据预测任务，数据集包含在源码中。
# 3.  **提交要求**
#    - 提交一个 `.ipynb` 文件，文件内容需包括：
#      - 每个理论学习点下方填写的你整理的学习内容（可结合简单代码辅助理解）
#      - 所有实践任务的结果展示（简单的实践任务代码可直接写在该文档）
#    - 注：对文字排版无具体要求；使用 Jupyter Notebook 打开，图片可直接通过粘贴插入 Markdown
#    - 文件命名格式：`Week2_姓名.ipynb`
#
# ---

# %% [markdown]
# ### 理论学习

# %% [markdown]
# #### 1. 卷积神经网络（CNN）的基本原理
# - CNN 的基本架构
# - 介绍卷积操作的计算方式、卷积核、步长、padding 等核心参数
# - 特殊卷积：1×1卷积

# %% [markdown]
# #### 2. 池化操作的概念与作用（Pooling）

# %% [markdown]
# #### 3. 批归一化（Batch Normalization）的原理与优势
# - 讲解其作用，以及其在模型中的位置

# %% [markdown]
# ### 4. ResNet 的设计思想
# - 残差连接（Residual Connection）的结构与作用
# - 解释 Bottleneck 的三层结构（1×1 → 3×3 → 1×1）以及其在深层网络中的作用

# %% [markdown]
# ---

# %% [markdown]
# ### 实践任务

# %% [markdown]
# #### 任务一：复现ResNet模型（运行 Traning 和 Test 即可）
#
# **目标：** 根据根据[源码](https://github.com/CathIAS/TLIO)复现基于Resnet的[TLIO](https://ieeexplore.ieee.org/document/9134860)模型，实现imu数据预测，学习resnet的结构。
#
# **要求：**
#
# - 结合资料学习代码中resnet的实现(model_resnet.py)
# - 模型数据集根据Github源码中提供的数据集链接进行下载
# - 复现时采用Github源码的Readme中 Tranining 和 Testing 指令
# - 在代码中标注出前向过程中特征维度的变化
