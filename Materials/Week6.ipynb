# %% [markdown]
# <h1 align="center"> Week 6 - Time-LLM </h1>
#
# <p style="text-align:center">汇报人：xxx</p>
#
# ---

# %% [markdown]
# ###  建议学习资料：
#
# - [Time-LLM模型论文](https://arxiv.org/abs/2310.01728)
#
# ###  本周任务清单：
#
# 1.  **理论学习**
#    - 根据论文学习 Time-LLM 模型的基本原理
#
# 2.  **实践任务**
#    - 根据[论文源码](https://github.com/KimMeen/Time-LLM)复现 Time-LLM 模型，在源码地址给的数据集上进行时序信号预测
#
#
# 3.  **提交要求**
#    - 提交一个 `.ipynb` 文件，文件内容需包括：
#      - 每个理论学习点下方填写的你整理的学习内容（可结合简单代码辅助理解）
#      - 所有实践任务的完整代码实现与运行结果（包含适当注释）
#    - 注：对文字排版无具体要求；使用 Jupyter Notebook 打开，图片可直接通过粘贴插入 Markdown
#    - 文件命名格式：`Week6_姓名.ipynb`
#
# ---

# %% [markdown]
# ### 理论学习

# %% [markdown]
# #### 1. 时序信号（Time-series signal）
# - 理解时序信号的概念
# - 分析预测时序信号的常见模型优缺点：卷积神经网络（CNN）、循环神经网络（RNN）、长短期记忆网络（LSTM）以及Transformer

# %% [markdown]
# #### 2. 大语言模型（Large Language Model）
# - 了解LLM的基本概念和原理
# - 学习利用LLM生成相关token

# %% [markdown]
# #### 3. 跨模态对齐（Cross-modal alignment）
# - 了解多模态相关概念，以及多模态对于模型学习能力的提升
# - 理解跨模态对齐的概念，特别是如何通过 **注意力机制** 来实现跨模态对齐

# %% [markdown]
# #### 4. 块重编程（Patch Reprogramming）
# - 了解论文中Patch Reprogramming的具体过程和思想

# %% [markdown]
# ---

# %% [markdown]
# ### 实践任务

# %% [markdown]
# #### 任务一：根据源码复现Time-LLM模型（仅实现Quick Demo即可）
#
# **目标：** 根据Github上的源码复现Time-LLM模型，对时序信号数据进行预测任务。
#
# **要求：**
#
# - 结合论文自行学习源码内容
# - 自行创建虚拟环境并根据Github源码中要求配置环境
# - 模型数据集根据Github源码中给的数据集链接进行下载
# - 复现时采用Github源码介绍中Quick Demos中的TimeLLM_ETTh1脚本即可
# - 输出模型在给定数据集上的预测结果
