# %% [markdown]
# # 低方差过滤

# %%
import numpy as np

# %%
a = np.random.randn(100)
print(np.var(a))
# Out:
# 1.0212980993703484

# %%
b = np.random.randn(100) * 0.1
print(np.var(b))
# Out:
# 0.0076153253386425914

# %%
c = np.random.normal(5,0.1,size=100)
print(np.var(c))
# Out:
# 0.009695790880031979

# %%
# 构造特征向量（输入数据X）
X = np.vstack((a,c)).T
# Out:
# [[-0.47353734  5.07052715]
#  [ 0.52780738  5.09536485]
#  [-0.1461888   5.0167654 ]
#  [-0.0915047   4.9969639 ]
#  [-0.32136837  5.03965291]
#  [ 0.94957493  4.93155596]
#  [ 1.5052338   5.0009674 ]
#  [ 0.95694266  5.11263779]
#  [-0.46871916  4.93377269]
#  [-0.43643917  5.10117527]
#  [ 0.34324716  4.72605933]
#  [ 0.19164341  4.92271685]
#  [-0.25563769  4.91677707]
#  [ 1.26538057  5.06883437]
#  [-0.37349064  4.9795369 ]
#  [ 0.92904269  5.05601602]
#  [-1.68178166  4.9873306 ]
#  [ 1.15210178  5.03718468]
#  [ 1.71569992  5.08007124]
#  [ 1.00650532  5.02948484]
#  [ 0.1395363   4.93912084]
#  [ 0.06913717  5.07619411]
#  [-0.82600772  5.04392228]
#  [ 1.4592076   5.03131052]
#  [ 0.42579563  5.03124654]
#  [-0.79960679  4.92280531]
#  [-0.36803608  5.00342264]
#  [ 0.62484365  5.07620191]
#  [-0.6618072   5.089294  ]
#  [-0.06586969  4.98043611]
#  [-1.10991548  5.0497272 ]
#  [ 1.68053075  5.02425971]
#  [-2.00926754  4.91794452]
#  [ 1.73049994  4.87909587]
# ...
