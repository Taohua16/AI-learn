# %%
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread("input.png")

# %%
plt.figure(figsize=(10, 6)) 
plt.imshow(img)
plt.title('Image')
plt.axis('off')            
plt.show()

# %%
x1, y1 = 355, 239
x2, y2 = 550, 388

# %%
cropped = img[y1:y2, x1:x2]

# %%
cropped_rgb = cv2.cvtColor(cropped, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(5, 3))  
plt.imshow(cropped_rgb)
plt.title('Cropped Image')  
plt.axis('off')            
plt.show()

# %%
x1, y1 = 36, 257
x2, y2 = 195, 365
cropped2 = img[y1:y2, x1:x2]

# %%
cropped_rgb2 = cv2.cvtColor(cropped2, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(5, 3))  
plt.imshow(cropped_rgb2)
plt.title('Cropped2 Image')  
plt.axis('off')            
plt.show()

# %%
x1, y1 = 33, 261
x2, y2 = 279, 372
cropped3 = img[y1:y2, x1:x2]

# %%
cropped_rgb3 = cv2.cvtColor(cropped3, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(5, 3))  
plt.imshow(cropped_rgb3)
plt.title('Cropped3 Image')  
plt.axis('off')            
plt.show()
